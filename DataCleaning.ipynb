# %% [markdown]
# # Exploring the Dataset

# %%
from flatten_json import flatten
import pandas as pd
import seaborn as sns

import os

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType,StructField, StringType, IntegerType,BooleanType,DoubleType
spark = SparkSession.builder \
    .master("local[1]") \
    .appName("FraudTransactionModel") \
    .getOrCreate()

# Read JSON file into dataframe    
df = spark.read.json("Data/transactions.txt")
df.printSchema()
df.show()
# Out:
# root
#  |-- accountNumber: string (nullable = true)
#  |-- accountOpenDate: string (nullable = true)
#  |-- acqCountry: string (nullable = true)
#  |-- availableMoney: double (nullable = true)
#  |-- cardCVV: string (nullable = true)
#  |-- cardLast4Digits: string (nullable = true)
#  |-- cardPresent: boolean (nullable = true)
#  |-- creditLimit: double (nullable = true)
#  |-- currentBalance: double (nullable = true)
#  |-- currentExpDate: string (nullable = true)
#  |-- customerId: string (nullable = true)
#  |-- dateOfLastAddressChange: string (nullable = true)
#  |-- echoBuffer: string (nullable = true)
#  |-- enteredCVV: string (nullable = true)
#  |-- expirationDateKeyInMatch: boolean (nullable = true)
#  |-- isFraud: boolean (nullable = true)
#  |-- merchantCategoryCode: string (nullable = true)
#  |-- merchantCity: string (nullable = true)
#  |-- merchantCountryCode: string (nullable = true)
#  |-- merchantName: string (nullable = true)
#  |-- merchantState: string (nullable = true)
#  |-- merchantZip: string (nullable = true)
#  |-- posConditionCode: string (nullable = true)
#  |-- posEntryMode: string (nullable = true)
#  |-- posOnPremises: string (nullable = true)
#  |-- recurringAuthInd: string (nullable = true)
#  |-- transactionAmount: double (nullable = true)
#  |-- transactionDateTime: string (nullable = true)
#  |-- transactionType: string (nullable = true)
#
# +-------------+---------------+----------+--------------+-------+---------------+-----------+-----------+--------------+--------------+----------+-----------------------+----------+----------+------------------------+-------+--------------------+------------+-------------------+--------------------+-------------+-----------+----------------+------------+-------------+----------------+-----------------+-------------------+--------------------+
# |accountNumber|accountOpenDate|acqCountry|availableMoney|cardCVV|cardLast4Digits|cardPresent|creditLimit|currentBalance|currentExpDate|customerId|dateOfLastAddressChange|echoBuffer|enteredCVV|expirationDateKeyInMatch|isFraud|merchantCategoryCode|merchantCity|merchantCountryCode|        merchantName|merchantState|merchantZip|posConditionCode|posEntryMode|posOnPremises|recurringAuthInd|transactionAmount|transactionDateTime|     transactionType|
# +-------------+---------------+----------+--------------+-------+---------------+-----------+-----------+--------------+--------------+----------+-----------------------+----------+----------+------------------------+-------+--------------------+------------+-------------------+--------------------+-------------+-----------+----------------+------------+-------------+----------------+-----------------+-------------------+--------------------+
# |    737265056|     2015-03-14|        US|        5000.0|    414|           1803|      false|     5000.0|           0.0|       06/2023| 737265056|             2015-03-14|          |       414|                   false|  false|           rideshare|            |                 US|                Uber|             |           |              01|          02|             |                |            98.55|2016-08-13T14:27:32|            PURCHASE|
# |    737265056|     2015-03-14|        US|        5000.0|    486|            767|       true|     5000.0|           0.0|       02/2024| 737265056|             2015-03-14|          |       486|                   false|  false|       entertainment|            |                 US|         AMC #191138|             |           |              01|          09|             |                |            74.51|2016-10-11T05:05:54|            PURCHASE|
# |    574788567|     2015-10-13|        US|       2428.67|    579|           4219|       true|     2500.0|         71.33|       08/2032| 574788567|             2015-10-13|          |       579|                   false|  false|                auto|            |                 US|Convenient Auto S...|             |           |              01|          05|             |                |           124.21|2016-01-29T07:17:39|            PURCHASE|
# |    574788567|     2015-10-13|        US|       2304.46|    579|           4219|       true|     2500.0|        195.54|       08/2022| 574788567|             2015-10-13|          |       539|                   false|  false|                auto|            |                 US|     Shell Auto Body|             |           |              01|          09|             |                |           196.07|2016-01-29T07:33:15|            PURCHASE|
# +-------------+---------------+----------+--------------+-------+---------------+-----------+-----------+--------------+--------------+----------+-----------------------+----------+----------+------------------------+-------+--------------------+------------+-------------------+--------------------+-------------+-----------+----------------+------------+-------------+----------------+-----------------+-------------------+--------------------+
# only showing top 20 rows

# %%
pandaDf = df.toPandas()

# %%
pandaDf.head()
# Out:
#   accountNumber accountOpenDate acqCountry  availableMoney cardCVV  \
# 0     737265056      2015-03-14         US          5000.0     414
# 1     737265056      2015-03-14         US          5000.0     486
# 2     737265056      2015-03-14         US          5000.0     486
# 3     737265056      2015-03-14         US          5000.0     486
# 4     830329091      2015-08-06         US          5000.0     885
#
#   cardLast4Digits  cardPresent  creditLimit  currentBalance currentExpDate  \
# 0            1803        False       5000.0             0.0        06/2023
# 1             767         True       5000.0             0.0        02/2024
# 2             767        False       5000.0             0.0        08/2025
# 3             767        False       5000.0             0.0        08/2025
# 4            3143         True       5000.0             0.0        10/2029
#
#    ...         merchantName merchantState merchantZip posConditionCode  \
# 0  ...                 Uber                                         01
# 1  ...          AMC #191138                                         01
# 2  ...           Play Store                                         01
# 3  ...           Play Store                                         01
# 4  ...  Tim Hortons #947751                                         01
#
#    posEntryMode  posOnPremises recurringAuthInd transactionAmount  \
# 0            02                                             98.55
# 1            09                                             74.51
# 2            09                                              7.47
# 3            09                                              7.47
# 4            02                                             71.18
#
#    transactionDateTime transactionType
# 0  2016-08-13T14:27:32        PURCHASE
# 1  2016-10-11T05:05:54        PURCHASE
# 2  2016-11-08T09:18:39        PURCHASE
# 3  2016-12-10T02:14:50        PURCHASE
# 4  2016-03-24T21:04:46        PURCHASE
#
# [5 rows x 29 columns]

# %%
pandaDf.count()
# Out:
# accountNumber               786363
# accountOpenDate             786363
# acqCountry                  786363
# availableMoney              786363
# cardCVV                     786363
# cardLast4Digits             786363
# cardPresent                 786363
# creditLimit                 786363
# currentBalance              786363
# currentExpDate              786363
# customerId                  786363
# dateOfLastAddressChange     786363
# echoBuffer                  786363
# enteredCVV                  786363
# expirationDateKeyInMatch    786363
# isFraud                     786363
# merchantCategoryCode        786363
# merchantCity                786363
# merchantCountryCode         786363
# merchantName                786363
# merchantState               786363
# merchantZip                 786363
# posConditionCode            786363
# posEntryMode                786363
# posOnPremises               786363
# recurringAuthInd            786363
# transactionAmount           786363
# transactionDateTime         786363
# transactionType             786363
# dtype: int64

# %%
   .rdd.(pandaDf, 'Data/pickles/dataset')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-d5d7e1c1e110> in <module>
# ----> 1 pandaDf.to_pickle(pandaDf, 'Data/pickles/dataset')
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in to_pickle(self, path, compression, protocol, storage_options)
#    2862         from pandas.io.pickle import to_pickle
#    2863
# -> 2864         to_pickle(
#    2865             self,
#    2866             path,
#
# ~/.local/lib/python3.8/site-packages/pandas/io/pickle.py in to_pickle(obj, filepath_or_buffer, compression, protocol, storage_options)
#      88         protocol = pickle.HIGHEST_PROTOCOL
#      89
# ---> 90     with get_handle(
#      91         filepath_or_buffer,
#      92         "wb",
#
# ~/.local/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     556
#     557     # open URLs
# --> 558     ioargs = _get_filepath_or_buffer(
#     559         path_or_buf,
#     560         encoding=encoding,
#
# ~/.local/lib/python3.8/site-packages/pandas/io/common.py in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     245     # handle compression dict
#     246     compression_method, compression = get_compression_method(compression)
# --> 247     compression_method = infer_compression(filepath_or_buffer, compression_method)
#     248
#     249     # GH21227 internal compression is not used for non-binary handles.
#
# ~/.local/lib/python3.8/site-packages/pandas/io/common.py in infer_compression(filepath_or_buffer, compression)
#     486     valid = ["infer", None] + sorted(_compression_to_extension)
#     487     msg += f"\nValid compression types are {valid}"
# --> 488     raise ValueError(msg)
#     489
#     490
#
# ValueError: Unrecognized compression type: Data/pickles/dataset
# Valid compression types are ['infer', None, 'bz2', 'gzip', 'xz', 'zip']

# %%
spark.sql("CREATE OR REPLACE TEMPORARY VIEW transactions USING json OPTIONS" + 
      " (path 'Data/transactions.txt')")
spark.sql("select * from transactions").show()
# Out:
# +-------------+---------------+----------+--------------+-------+---------------+-----------+-----------+--------------+--------------+----------+-----------------------+----------+----------+------------------------+-------+--------------------+------------+-------------------+--------------------+-------------+-----------+----------------+------------+-------------+----------------+-----------------+-------------------+--------------------+
# |accountNumber|accountOpenDate|acqCountry|availableMoney|cardCVV|cardLast4Digits|cardPresent|creditLimit|currentBalance|currentExpDate|customerId|dateOfLastAddressChange|echoBuffer|enteredCVV|expirationDateKeyInMatch|isFraud|merchantCategoryCode|merchantCity|merchantCountryCode|        merchantName|merchantState|merchantZip|posConditionCode|posEntryMode|posOnPremises|recurringAuthInd|transactionAmount|transactionDateTime|     transactionType|
# +-------------+---------------+----------+--------------+-------+---------------+-----------+-----------+--------------+--------------+----------+-----------------------+----------+----------+------------------------+-------+--------------------+------------+-------------------+--------------------+-------------+-----------+----------------+------------+-------------+----------------+-----------------+-------------------+--------------------+
# |    737265056|     2015-03-14|        US|        5000.0|    414|           1803|      false|     5000.0|           0.0|       06/2023| 737265056|             2015-03-14|          |       414|                   false|  false|           rideshare|            |                 US|                Uber|             |           |              01|          02|             |                |            98.55|2016-08-13T14:27:32|            PURCHASE|
# |    737265056|     2015-03-14|        US|        5000.0|    486|            767|       true|     5000.0|           0.0|       02/2024| 737265056|             2015-03-14|          |       486|                   false|  false|       entertainment|            |                 US|         AMC #191138|             |           |              01|          09|             |                |            74.51|2016-10-11T05:05:54|            PURCHASE|
# |    737265056|     2015-03-14|        US|        5000.0|    486|            767|      false|     5000.0|           0.0|       08/2025| 737265056|             2015-03-14|          |       486|                   false|  false|          mobileapps|            |                 US|          Play Store|             |           |              01|          09|             |                |             7.47|2016-11-08T09:18:39|            PURCHASE|
# |    737265056|     2015-03-14|        US|        5000.0|    486|            767|      false|     5000.0|           0.0|       08/2025| 737265056|             2015-03-14|          |       486|                   false|  false|          mobileapps|            |                 US|          Play Store|             |           |              01|          09|             |                |             7.47|2016-12-10T02:14:50|            PURCHASE|
# |    830329091|     2015-08-06|        US|        5000.0|    885|           3143|       true|     5000.0|           0.0|
# |    574788567|     2015-10-13|        US|       2304.46|    579|           4219|       true|     2500.0|        195.54|       08/2022| 574788567|             2015-10-13|          |       539|                   false|  false|                auto|            |                 US|     Shell Auto Body|             |           |              01|          09|             |                |           196.07|2016-01-29T07:33:15|            PURCHASE|
# +-------------+---------------+----------+--------------+-------+---------------+-----------+-----------+--------------+--------------+----------+-----------------------+----------+----------+------------------------+-------+--------------------+------------+-------------------+--------------------+-------------+-----------+----------------+------------+-------------+----------------+-----------------+-------------------+--------------------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import sum, col, desc
df.groupBy("isFraud").count().show()
# Out:
# +-------+------+
# |isFraud| count|
# +-------+------+
# |   true| 12417|
# |  false|773946|
# +-------+------+

# %%
df.groupBy("merchantCity").count().show()
# Out:
# +------------+------+
# |merchantCity| count|
# +------------+------+
# |            |786363|
# +------------+------+

# %%
df = pd.read_pickle('Data/pickles/dataset')

df.head()
# Out:
#    accountNumber  customerId  creditLimit  availableMoney  \
# 0      737265056   737265056         5000          5000.0
# 1      737265056   737265056         5000          5000.0
# 2      737265056   737265056         5000          5000.0
# 3      737265056   737265056         5000          5000.0
# 4      830329091   830329091         5000          5000.0
#
#    transactionDateTime  transactionAmount         merchantName acqCountry  \
# 0  2016-08-13T14:27:32              98.55                 Uber         US
# 1  2016-10-11T05:05:54              74.51          AMC #191138         US
# 2  2016-11-08T09:18:39               7.47           Play Store         US
# 3  2016-12-10T02:14:50               7.47           Play Store         US
# 4  2016-03-24T21:04:46              71.18  Tim Hortons #947751         US
#
#   merchantCountryCode posEntryMode  ... echoBuffer currentBalance  \
# 0                  US           02  ...        NaN            0.0
# 1                  US           09  ...        NaN            0.0
# 2                  US           09  ...        NaN            0.0
# 3                  US           09  ...        NaN            0.0
# 4                  US           02  ...        NaN            0.0
#
#   merchantCity merchantState merchantZip  cardPresent  posOnPremises  \
# 0          NaN           NaN         NaN        False            NaN
# 1          NaN           NaN         NaN         True            NaN
# 2          NaN           NaN         NaN        False            NaN
# 3          NaN           NaN         NaN        False            NaN
# 4          NaN           NaN         NaN         True            NaN
#
#    recurringAuthInd expirationDateKeyInMatch  isFraud
# 0               NaN                    False    False
# 1               NaN                    False    False
# 2               NaN                    False    False
# 3               NaN                    False    False
# 4               NaN                    False    False
#
# [5 rows x 29 columns]

# %%
"Dataset Dimensions: {}x{}".format(df.shape[0], df.shape[1])
# Out:
# 'Dataset Dimensions: 786363x29'

# %% [markdown]
# ## Checking for nans

# %%
df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-629914d6d1c7> in <module>
# ----> 1 df.isnull().sum()
#
# ~/.local/lib/python3.8/site-packages/pyspark/sql/dataframe.py in __getattr__(self, name)
#    1657         """
#    1658         if name not in self.columns:
# -> 1659             raise AttributeError(
#    1660                 "'%s' object has no attribute '%s'" % (self.__class__.__name__, name))
#    1661         jc = self._jdf.apply(name)
#
# AttributeError: 'DataFrame' object has no attribute 'isnull'

# %% [markdown]
# One can only hope for clean data...
#
# Considering our shape dimensions, I can pretty muh remove merchantCity, merchantState, merchantZip, posOnPremises, and recurringAuthInd right off the bat since there are too many missing values to do anything else while remaining accurate.
# I willi keep ID related columns for now in case I am interested in looking at a specific customer's transactions.
#
# I want to keep cardCVV and enteredCVV just in case at the moment as I'm interested to see how many of them differ from each other.

# %%
df.drop(['merchantCity', 'merchantState', 'merchantZip', 'posOnPremises', 'recurringAuthInd'], axis=1, inplace=True)

df.isnull().sum()

df = df.reset_index(drop=True)

df
# Out:
#         accountNumber  customerId  creditLimit  availableMoney  \
# 0           737265056   737265056         5000         5000.00
# 1           737265056   737265056         5000         5000.00
# 2           737265056   737265056         5000         5000.00
# 3           737265056   737265056         5000         5000.00
# 4           830329091   830329091         5000         5000.00
# ...               ...         ...          ...             ...
# 786358      732852505   732852505        50000        48904.96
# 786359      732852505   732852505        50000        48785.04
# 786360      732852505   732852505        50000        48766.15
# 786361      732852505   732852505        50000        48716.72
# 786362      732852505   732852505        50000        48666.83
#
#         transactionDateTime  transactionAmount         merchantName  \
# 0       2016-08-13T14:27:32              98.55                 Uber
# 1       2016-10-11T05:05:54              74.51          AMC #191138
# 2       2016-11-08T09:18:39               7.47           Play Store
# 3       2016-12-10T02:14:50               7.47           Play Store
# 4       2016-03-24T21:04:46              71.18  Tim Hortons #947751
# ...                     ...                ...                  ...
# 786358  2016-12-22T18:44:12             119.92                 Lyft
# 786359  2016-12-25T16:20:34              18.89             hulu.com
# 786360  2016-12-27T15:46:24              49.43                 Lyft
# 786361  2016-12-29T00:30:55              49.89          walmart.com
# 786362  2016-12-30T20:10:29              72.18                 Uber
#
#        acqCountry merchantCountryCode posEntryMode  ...  \
# 0              US                  US           02  ...
# 1              US                  US           09  ...
# 2              US                  US           09  ...
# 3              US                  US           09  ...
# 4              US                  US           02  ...
# ...           ...                 ...          ...  ...
# 786358         US                  US           90  ...
# 786359         US                  US           09  ...
# 786360         US                  US           02  ...
# 786361         US                  US           09  ...
# 786362         US                  US           05  ...
#
#        dateOfLastAddressChange cardCVV enteredCVV cardLast4Digits  \
# 0                   2015-03-14     414        414            1803
# 1                   2015-03-14     486        486             767
# 2                   2015-03-14     486        486             767
# 3                   2015-03-14     486        486             767
# 4                   2015-08-06     885        885            3143
# ...                        ...     ...        ...             ...
# 786358              2012-08-23     936        936            3783
# 786359              2012-08-23     939        939            3388
# 786360              2012-08-23     936        936            3783
# 786361              2012-08-23     939        939            3388
# 786362              2012-08-23     939        939            3388
#
#        transactionType  echoBuffer  currentBalance  cardPresent  \
# 0             PURCHASE         NaN            0.00        False
# 1             PURCHASE         NaN            0.00         True
# 2             PURCHASE         NaN            0.00        False
# 3             PURCHASE         NaN            0.00        False
# 4             PURCHASE         NaN            0.00         True
# ...                ...         ...             ...          ...
# 786358        PURCHASE         NaN         1095.04        False
# 786359        PURCHASE         NaN         1214.96        False
# 786360        PURCHASE         NaN         1233.85        False
# 786361        PURCHASE         NaN         1283.28        False
# 786362        PURCHASE         NaN         1333.17        False
#
#        expirationDateKeyInMatch  isFraud
# 0                         False    False
# 1                         False    False
# 2                         False    False
# 3                         False    False
# 4                         False    False
# ...                         ...      ...
# 786358                    False    False
# 786359                    False    False
# 786360                    False    False
# 786361                    False    False
# 786362                    False    False
#
# [786363 rows x 24 columns]

# %%
pd.to_pickle(df, 'Data/pickles/clean_data', protocol=4)
